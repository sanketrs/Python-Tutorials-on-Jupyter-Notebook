# %% [markdown]
# # Variants of Division Operation in Python 3 | Python Tutorials

# %%
# Author: https://www.linkedin.com/in/sanketshindepune/

# %%
#Different Variants of Arithmetic Operations (+,-,*,/,**,%,//)

# %%
#Division Operation

# %%
i=3
j=6
k=i/j #result always float
print(k)
# Out:
# 0.5

# %%
i=j=4
k=i/j
print(k)
# Out:
# 1.0

# %%
print(5/6)
# Out:
# 0.8333333333333334

# %%
print(5/(/4)) #important syntax error
# Out:
#   File "<ipython-input-8-bdc04ec61686>", line 1
#     print(5/(/4)) #important syntax error
#              ^
# SyntaxError: invalid syntax

# %%
print("Hello"/6) # TypeError: unsupported operand type(s) for /: 'str' and 'int'
print("4"/6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-24e8f3161a15> in <module>
# ----> 1 print("Hello"/6) # TypeError: unsupported operand type(s) for /: 'str' and 'int'
#       2 print("4"/6)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
j=7/7
print(j/2)
# Out:
# 0.5

# %%
j=5
print(j/6)
# Out:
# 0.8333333333333334

# %%
p
print(p/4)  #important name-error [NameError: name 'p' is not defined]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-65fcd59b46e9> in <module>
# ----> 1 p
#       2 print(p/4)  #important name-error [NameError: name 'p' is not defined]
#
# NameError: name 'p' is not defined

# %%
print("ab"/"cd") # TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c979b0afd499> in <module>
# ----> 1 print("ab"/"cd") # TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
print(5.7/6.0) #division of float,float -> result is float
# Out:
# 0.9500000000000001

# %%
print(5.6/4)
# Out:
# 1.4

# %%
# While integers can be of any length, a floating point number is accurate only up to 15 decimal places 
# (the 16th place is inaccurate).

# %%
print(4.55/5.609) #important concept of fraction upto 15 decimal values
# Out:
# 0.8111962916740951

# %%
print(123456789101112131415/2) # integers can be of any length
# Out:
# 6.1728394550556066e+19

# %%
z="ab"/"d"  #TypeError: unsupported operand type(s) for /: 'str' and 'str'
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-554c3e8ba9cb> in <module>
# ----> 1 z="ab"/"d"  #TypeError: unsupported operand type(s) for /: 'str' and 'str'
#       2 print(z)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
c=2
c/=8
print(c)
# Out:
# 0.25

# %%
# postdivision operator(//) isnt part of python 3

# %%
c=3
print(c//)
# Out:
#   File "<ipython-input-25-e98523bb5830>", line 2
#     print(c//)
#              ^
# SyntaxError: invalid syntax

# %%
print("End of Arithmetic Operations in Python 3 with Jupyter Notebook - Part 4")
# Out:
# End of Arithmetic Operations in Python 3 with Jupyter Notebook - Part 4

# %%
print(4/2) #bonus - result as float
print(4//2) #bonus - result as integer
# Out:
# 2.0
# 2

# %%
print(76//9) # intger division
# Out:
# 8

# %%
8//3 #bonus  integer division
# Out:
# 2

# %%
8%3 #Remainder
# Out:
# 2

# %%
8%3//2 #operator precedence - first % and then //
# Out:
# 1

# %%
8%%3 #syntax error
# Out:
#   File "<ipython-input-39-0834ddd5651f>", line 1
#     8%%3
#       ^
# SyntaxError: invalid syntax
